# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-10., 10., 0.2)
y = 2 + 5* x
plt.plot(x, y)

# %%
def sigmoid(x): 
    s = 1 / (1 + np.exp(-(2 + 5*x)))
    return s


plt.plot(x, sigmoid(x))
